# %% [markdown]
# dddddddsdfdddd

# %% [markdown]
# ### Importing Libraries

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize

from skimage.morphology import label
from sklearn.model_selection import train_test_split
from IPython.display import Image, display

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Importing Dataset

# %%
im_width = 256
im_height = 256

image_filename_train = []

mask_files = glob(pathname='./lgg-mri-segmentation/kaggle_3m/*/*_mask*')
for i in mask_files:
    image_filename_train.append(i.replace('_mask',''))
print(image_filename_train[:10])
len(image_filename_train)
# Out:
# ['./lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_10.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_12.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_13.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_14.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_15.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_16.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_17.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_18.tif', './lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_19.tif']
# 3929

# %%
def plot_from_img_path(rows, columns, list_img_path, list_mask_path):
    fig = plt.figure(figsize  = (12,12))
    for i in range(1, rows * columns + 1):
        fig.add_subplot(rows, columns, i)
        img_path = list_img_path[i]
        mask_path = list_mask_path[i]
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path)
        plt.imshow(image)
        plt.imshow(mask, alpha=0.4)
    plt.show()

# %%
plot_from_img_path(3, 3, image_filename_train, mask_files)

# %% [markdown]
# ### Preprocessing the Data

# %%
df = pd.DataFrame(data = {'image_filename_train': image_filename_train, 'mask': mask_files})
df_train, df_test = train_test_split(df, test_size = 0.05)
df_train, df_val = train_test_split(df_train, test_size = 0.05)

# %%
print(df_train.shape)
print(df_val.shape)
print(df_test.shape)
# Out:
# (3545, 2)
# (187, 2)
# (197, 2)

# %%
def train_generator(
    data_frame,
    batch_size,
    augmentation_dict,
    image_color_mode="rgb",
    mask_color_mode="grayscale",
    image_save_prefix="image",
    mask_save_prefix="mask",
    save_to_dir=None,
    target_size=(256, 256),
    seed=1,
):
    
    image_datagen = ImageDataGenerator(**augmentation_dict)
    mask_datagen = ImageDataGenerator(**augmentation_dict)

    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col="image_filename_train",
        class_mode=None,
        color_mode=image_color_mode,
        target_size=target_size,
        batch_size=batch_size,
        save_to_dir=save_to_dir,
        save_prefix=image_save_prefix,
        seed=seed,
    )

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col="mask",
        class_mode=None,
        color_mode=mask_color_mode,
        target_size=target_size,
        batch_size=batch_size,
        save_to_dir=save_to_dir,
        save_prefix=mask_save_prefix,
        seed=seed,
    )

    train_gen = zip(image_generator, mask_generator)
    
    # Final return Tuple after image Normalization and Diagnostics
    for (img, mask) in train_gen:
        img, mask = normalize_and_diagnose(img, mask)
        yield (img, mask)

# %%
def normalize_and_diagnose(img, mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    return(img, mask)

def dice_coefficients(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_coefficients_loss(y_true, y_pred, smooth=100):
    return -dice_coefficients(y_true, y_pred, smooth)
def iou(y_true, y_pred, smooth=100):
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    return iou
def jaccard_distance(y_true, y_pred):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    return -iou(y_true_flatten, y_pred_flatten)

# %% [markdown]
# ### UNet Architecture

# %%
display(Image(filename='Unet_Architecture.png'))

# %%
def unet(input_size=(im_width, im_height, 3)):
    
    inputs = Input(input_size)

    # First DownConvolution / Encoder Leg will begin, so start with Conv2D
    conv1 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(inputs)
    bn1 = Activation("relu")(conv1)
    conv1 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)
    # First DownSampling
    conv2 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(pool1)
    bn2 = Activation("relu")(conv2)
    conv2 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation("relu")(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)
    #Second DownSampling
    conv3 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(pool2)
    bn3 = Activation("relu")(conv3)
    conv3 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation("relu")(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)
    # Third DownSampling
    conv4 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(pool3)
    bn4 = Activation("relu")(conv4)
    conv4 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation("relu")(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(filters=1024, kernel_size=(3, 3), padding="same")(pool4)
    bn5 = Activation("relu")(conv5)
    conv5 = Conv2D(filters=1024, kernel_size=(3, 3), padding="same")(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation("relu")(bn5)

    up6 = concatenate([Conv2DTranspose(512, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn5), conv4], axis=3)
    """ After every concatenation we again apply two consecutive regular convolutions so that the model can learn to assemble a more precise output """
    conv6 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(up6)
    bn6 = Activation("relu")(conv6)
    conv6 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation("relu")(bn6)

    up7 = concatenate([Conv2DTranspose(256, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn6),conv3], axis=3)
    conv7 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(up7)
    bn7 = Activation("relu")(conv7)
    conv7 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation("relu")(bn7)

    up8 = concatenate([Conv2DTranspose(128, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn7),conv2], axis=3)
    conv8 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(up8)
    bn8 = Activation("relu")(conv8)
    conv8 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation("relu")(bn8)

    up9 = concatenate([Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn8),conv1],axis=3)
    conv9 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(up9)
    bn9 = Activation("relu")(conv9)
    conv9 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation("relu")(bn9)

    conv10 = Conv2D(filters=1, kernel_size=(1, 1), activation="sigmoid")(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# ### Training the UNet model

# %%
EPOCHS = 150
BATCH_SIZE = 32
learning_rate = 1e-4

train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



# decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coefficients_loss, metrics=["binary_accuracy", iou, dice_coefficients])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# /usr/lib/python3/dist-packages/keras/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Found 3545 validated image filenames.
# Found 3545 validated image filenames.
# Epoch 1/150
# 111/110 [==============================] - ETA: 0s - loss: -0.1441 - binary_accuracy: 0.9434 - iou: 0.0794 - dice_coefficients: 0.1441Found 187 validated image filenames.
# Found 187 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.03032, saving model to unet_brain_mri_seg.hdf5
# /usr/lib/python3/dist-packages/keras/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 110/110 [==============================] - 73s 601ms/step - loss: -0.1441 - binary_accuracy: 0.9434 - iou: 0.0794 - dice_coefficients: 0.1441 - val_loss: -0.0303 - val_binary_accuracy: 0.9861 - val_iou: 0.0155 - val_dice_coefficients: 0.0304
# Epoch 2/150
# 111/110 [==============================] - ETA: 0s - loss: -0.2453 - binary_accuracy: 0.9879 - iou: 0.1418 - dice_coefficients: 0.2454
# Epoch 2: val_loss improved from -0.03032 to -0.03431, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 61s 557ms/step - loss: -0.2453 - binary_accuracy: 0.9879 - iou: 0.1418 - dice_coefficients: 0.2454 - val_loss: -0.0343 - val_binary_accuracy: 0.9875 - val_iou: 0.0177 - val_dice_coefficients: 0.0342
# Epoch 3/150
# 111/110 [==============================] - ETA: 0s - loss: -0.3122 - binary_accuracy: 0.9909 - iou: 0.1883 - dice_coefficients: 0.3124
# Epoch 3: val_loss improved from -0.03431 to -0.11296, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 533ms/step - loss: -0.3122 - binary_accuracy: 0.9909 - iou: 0.1883 - dice_coefficients: 0.3124 - val_loss: -0.1130 - val_binary_accuracy: 0.9845 - val_iou: 0.0603 - val_dice_coefficients: 0.1126
# Epoch 4/150
# 111/110 [==============================] - ETA: 0s - loss: -0.3791 - binary_accuracy: 0.9926 - iou: 0.2389 - dice_coefficients: 0.3794
# Epoch 4: val_loss improved from -0.11296 to -0.43003, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 536ms/step - loss: -0.3791 - binary_accuracy: 0.9926 - iou: 0.2389 - dice_coefficients: 0.3794 - val_loss: -0.4300 - val_binary_accuracy: 0.9910 - val_iou: 0.2751 - val_dice_coefficients: 0.4292
# Epoch 5/150
# 111/110 [==============================] - ETA: 0s - loss: -0.4615 - binary_accuracy: 0.9942 - iou: 0.3056 - dice_coefficients: 0.4616
# Epoch 5: val_loss improved from -0.43003 to -0.57984, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 535ms/step - loss: -0.4615 - binary_accuracy: 0.9942 - iou: 0.3056 - dice_coefficients: 0.4616 - val_loss: -0.5798 - val_binary_accuracy: 0.9929 - val_iou: 0.4104 - val_dice_coefficients: 0.5793
# Epoch 6/150
# 111/110 [==============================] - ETA: 0s - loss: -0.5322 - binary_accuracy: 0.9950 - iou: 0.3688 - dice_coefficients: 0.5323
# Epoch 6: val_loss improved from -0.57984 to -0.65921, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 535ms/step - loss: -0.5322 - binary_accuracy: 0.9950 - iou: 0.3688 - dice_coefficients: 0.5323 - val_loss: -0.6592 - val_binary_accuracy: 0.9945 - val_iou: 0.4938 - val_dice_coefficients: 0.6568
# Epoch 7/150
# 111/110 [==============================] - ETA: 0s - loss: -0.5825 - binary_accuracy: 0.9952 - iou: 0.4185 - dice_coefficients: 0.5828
# Epoch 7: val_loss improved from -0.65921 to -0.68691, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 535ms/step - loss: -0.5825 - binary_accuracy: 0.9952 - iou: 0.4185 - dice_coefficients: 0.5828 - val_loss: -0.6869 - val_binary_accuracy: 0.9946 - val_iou: 0.5251 - val_dice_coefficients: 0.6869
# Epoch 8/150
# 111/110 [==============================] - ETA: 0s - loss: -0.6454 - binary_accuracy: 0.9958 - iou: 0.4846 - dice_coefficients: 0.6456
# Epoch 8: val_loss improved from -0.68691 to -0.73604, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 536ms/step - loss: -0.6454 - binary_accuracy: 0.9958 - iou: 0.4846 - dice_coefficients: 0.6456 - val_loss: -0.7360 - val_binary_accuracy: 0.9963 - val_iou: 0.5849 - val_dice_coefficients: 0.7302
# Epoch 9/150
# 111/110 [==============================] - ETA: 0s - loss: -0.6983 - binary_accuracy: 0.9963 - iou: 0.5428 - dice_coefficients: 0.6983
# Epoch 9: val_loss did not improve from -0.73604
# 110/110 [==============================] - 57s 520ms/step - loss: -0.6983 - binary_accuracy: 0.9963 - iou: 0.5428 - dice_coefficients: 0.6983 - val_loss: -0.7223 - val_binary_accuracy: 0.9951 - val_iou: 0.5681 - val_dice_coefficients: 0.7213
# Epoch 10/150
# 111/110 [==============================] - ETA: 0s - loss: -0.7232 - binary_accuracy: 0.9965 - iou: 0.5738 - dice_coefficients: 0.7232
# Epoch 10: val_loss improved from -0.73604 to -0.74508, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 60s 541ms/step - loss: -0.7232 - binary_accuracy: 0.9965 - iou: 0.5738 - dice_coefficients: 0.7232 - val_loss: -0.7451 - val_binary_accuracy: 0.9932 - val_iou: 0.5938 - val_dice_coefficients: 0.7441
# Epoch 11/150
# 111/110 [==============================] - ETA: 0s - loss: -0.7469 - binary_accuracy: 0.9967 - iou: 0.6041 - dice_coefficients: 0.7468
# Epoch 11: val_loss improved from -0.74508 to -0.82020, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 534ms/step - loss: -0.7469 - binary_accuracy: 0.9967 - iou: 0.6041 - dice_coefficients: 0.7468 - val_loss: -0.8202 - val_binary_accuracy: 0.9962 - val_iou: 0.6977 - val_dice_coefficients: 0.8212
# Epoch 12/150
# 111/110 [==============================] - ETA: 0s - loss: -0.7700 - binary_accuracy: 0.9968 - iou: 0.6338 - dice_coefficients: 0.7699
# Epoch 12: val_loss improved from -0.82020 to -0.82130, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 59s 536ms/step - loss: -0.7700 - binary_accuracy: 0.9968 - iou: 0.6338 - dice_coefficients: 0.7699 - val_loss: -0.8213 - val_binary_accuracy: 0.9961 - val_iou: 0.7004 - val_dice_coefficients: 0.8220
# Epoch 13/150
# 111/110 [==============================] - ETA: 0s - loss: -0.7687 - binary_accuracy: 0.9966 - iou: 0.6359 - dice_coefficients: 0.7689
# Epoch 13: val_loss did not improve from -0.82130
# 110/110 [==============================] - 58s 527ms/step - loss: -0.7687 - binary_accuracy: 0.9966 - iou: 0.6359 - dice_coefficients: 0.7689 - val_loss: -0.8045 - val_binary_accuracy: 0.9953 - val_iou: 0.6753 - val_dice_coefficients: 0.8049
# Epoch 14/150
# 111/110 [==============================] - ETA: 0s - loss: -0.7891 - binary_accuracy: 0.9968 - iou: 0.6591 - dice_coefficients: 0.7892
# Epoch 14: val_loss improved from -0.82130 to -0.85417, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 60s 548ms/step - loss: -0.7891 - binary_accuracy: 0.9968 - iou: 0.6591 - dice_coefficients: 0.7892 - val_loss: -0.8542 - val_binary_accuracy: 0.9967 - val_iou: 0.7485 - val_dice_coefficients: 0.8552
# Epoch 15/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8017 - binary_accuracy: 0.9970 - iou: 0.6773 - dice_coefficients: 0.8018
# Epoch 15: val_loss did not improve from -0.85417
# 110/110 [==============================] - 57s 522ms/step - loss: -0.8017 - binary_accuracy: 0.9970 - iou: 0.6773 - dice_coefficients: 0.8018 - val_loss: -0.7526 - val_binary_accuracy: 0.9948 - val_iou: 0.6132 - val_dice_coefficients: 0.7553
# Epoch 16/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8147 - binary_accuracy: 0.9971 - iou: 0.6938 - dice_coefficients: 0.8148
# Epoch 16: val_loss did not improve from -0.85417
# 110/110 [==============================] - 58s 526ms/step - loss: -0.8147 - binary_accuracy: 0.9971 - iou: 0.6938 - dice_coefficients: 0.8148 - val_loss: -0.8497 - val_binary_accuracy: 0.9968 - val_iou: 0.7425 - val_dice_coefficients: 0.8510
# Epoch 17/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8342 - binary_accuracy: 0.9974 - iou: 0.7232 - dice_coefficients: 0.8342
# Epoch 17: val_loss improved from -0.85417 to -0.86000, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 60s 543ms/step - loss: -0.8342 - binary_accuracy: 0.9974 - iou: 0.7232 - dice_coefficients: 0.8342 - val_loss: -0.8600 - val_binary_accuracy: 0.9966 - val_iou: 0.7566 - val_dice_coefficients: 0.8605
# Epoch 18/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8025 - binary_accuracy: 0.9968 - iou: 0.6810 - dice_coefficients: 0.8026
# Epoch 18: val_loss did not improve from -0.86000
# 110/110 [==============================] - 57s 521ms/step - loss: -0.8025 - binary_accuracy: 0.9968 - iou: 0.6810 - dice_coefficients: 0.8026 - val_loss: -0.8488 - val_binary_accuracy: 0.9960 - val_iou: 0.7383 - val_dice_coefficients: 0.8490
# Epoch 19/150
# 111/110 [==============================] - ETA: 0s - loss: -0.
150
# 111/110 [==============================] - ETA: 0s - loss: -0.8693 - binary_accuracy: 0.9977 - iou: 0.7754 - dice_coefficients: 0.8693
# Epoch 26: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 529ms/step - loss: -0.8693 - binary_accuracy: 0.9977 - iou: 0.7754 - dice_coefficients: 0.8693 - val_loss: -0.8767 - val_binary_accuracy: 0.9966 - val_iou: 0.7827 - val_dice_coefficients: 0.8774
# Epoch 27/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8716 - binary_accuracy: 0.9977 - iou: 0.7775 - dice_coefficients: 0.8715
# Epoch 27: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 528ms/step - loss: -0.8716 - binary_accuracy: 0.9977 - iou: 0.7775 - dice_coefficients: 0.8715 - val_loss: -0.8833 - val_binary_accuracy: 0.9972 - val_iou: 0.7953 - val_dice_coefficients: 0.8844
# Epoch 28/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8691 - binary_accuracy: 0.9976 - iou: 0.7734 - dice_coefficients: 0.8691
# Epoch 28: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 531ms/step - loss: -0.8691 - binary_accuracy: 0.9976 - iou: 0.7734 - dice_coefficients: 0.8691 - val_loss: -0.8747 - val_binary_accuracy: 0.9969 - val_iou: 0.7775 - val_dice_coefficients: 0.8744
# Epoch 29/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8710 - binary_accuracy: 0.9977 - iou: 0.7789 - dice_coefficients: 0.8711
# Epoch 29: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 527ms/step - loss: -0.8710 - binary_accuracy: 0.9977 - iou: 0.7789 - dice_coefficients: 0.8711 - val_loss: -0.8807 - val_binary_accuracy: 0.9970 - val_iou: 0.7902 - val_dice_coefficients: 0.8817
# Epoch 30/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8711 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coefficients: 0.8711
# Epoch 30: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 528ms/step - loss: -0.8711 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coefficients: 0.8711 - val_loss: -0.8896 - val_binary_accuracy: 0.9972 - val_iou: 0.8012 - val_dice_coefficients: 0.8886
# Epoch 31/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7890 - dice_coefficients: 0.8785
# Epoch 31: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 529ms/step - loss: -0.8785 - binary_accuracy: 0.9977 - iou: 0.7890 - dice_coefficients: 0.8785 - val_loss: -0.8807 - val_binary_accuracy: 0.9967 - val_iou: 0.7891 - val_dice_coefficients: 0.8812
# Epoch 32/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8614 - binary_accuracy: 0.9974 - iou: 0.7631 - dice_coefficients: 0.8615
# Epoch 32: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 529ms/step - loss: -0.8614 - binary_accuracy: 0.9974 - iou: 0.7631 - dice_coefficients: 0.8615 - val_loss: -0.8876 - val_binary_accuracy: 0.9971 - val_iou: 0.7999 - val_dice_coefficients: 0.8881
# Epoch 33/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8682 - binary_accuracy: 0.9975 - iou: 0.7751 - dice_coefficients: 0.8682
# Epoch 33: val_loss did not improve from -0.89193
# 110/110 [==============================] - 58s 526ms/step - loss: -0.8682 - binary_accuracy: 0.9975 - iou: 0.7751 - dice_coefficients: 0.8682 - val_loss: -0.8786 - val_binary_accuracy: 0.9963 - val_iou: 0.7835 - val_dice_coefficients: 0.8783
# Epoch 34/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8833 - binary_accuracy: 0.9978 - iou: 0.7963 - dice_coefficients: 0.8834
# Epoch 34: val_loss improved from -0.89193 to -0.89600, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 60s 541ms/step - loss: -0.8833 - binary_accuracy: 0.9978 - iou: 0.7963 - dice_coefficients: 0.8834 - val_loss: -0.8960 - val_binary_accuracy: 0.9972 - val_iou: 0.8121 - val_dice_coefficients: 0.8956
# Epoch 35/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8804 - binary_accuracy: 0.9978 - iou: 0.7932 - dice_coefficients: 0.8804
# Epoch 35: val_loss did not improve from -0.89600
# 110/110 [==============================] - 59s 540ms/step - loss: -0.8804 - binary_accuracy: 0.9978 - iou: 0.7932 - dice_coefficients: 0.8804 - val_loss: -0.8927 - val_binary_accuracy: 0.9972 - val_iou: 0.8074 - val_dice_coefficients: 0.8931
# Epoch 36/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8855 - binary_accuracy: 0.9979 - iou: 0.8016 - dice_coefficients: 0.8855
# Epoch 36: val_loss improved from -0.89600 to -0.90167, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 61s 552ms/step - loss: -0.8855 - binary_accuracy: 0.9979 - iou: 0.8016 - dice_coefficients: 0.8855 - val_loss: -0.9017 - val_binary_accuracy: 0.9974 - val_iou: 0.8224 - val_dice_coefficients: 0.9017
# Epoch 37/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8880 - binary_accuracy: 0.9978 - iou: 0.8051 - dice_coefficients: 0.8880
# Epoch 37: val_loss did not improve from -0.90167
# 110/110 [==============================] - 58s 525ms/step - loss: -0.8880 - binary_accuracy: 0.9978 - iou: 0.8051 - dice_coefficients: 0.8880 - val_loss: -0.8987 - val_binary_accuracy: 0.9970 - val_iou: 0.8175 - val_dice_coefficients: 0.8991
# Epoch 38/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8833 - binary_accuracy: 0.9978 - iou: 0.7992 - dice_coefficients: 0.8833
# Epoch 38: val_loss did not improve from -0.90167
# 110/110 [==============================] - 59s 535ms/step - loss: -0.8833 - binary_accuracy: 0.9978 - iou: 0.7992 - dice_coefficients: 0.8833 - val_loss: -0.7729 - val_binary_accuracy: 0.9941 - val_iou: 0.6324 - val_dice_coefficients: 0.7708
# Epoch 39/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8750 - binary_accuracy: 0.9977 - iou: 0.7870 - dice_coefficients: 0.8750
# Epoch 39: val_loss did not improve from -0.90167
# 110/110 [==============================] - 58s 523ms/step - loss: -0.8750 - binary_accuracy: 0.9977 - iou: 0.7870 - dice_coefficients: 0.8750 - val_loss: -0.8763 - val_binary_accuracy: 0.9971 - val_iou: 0.7824 - val_dice_coefficients: 0.8769
# Epoch 40/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8743 - binary_accuracy: 0.9976 - iou: 0.7856 - dice_coefficients: 0.8743
# Epoch 40: val_loss did not improve from -0.90167
# 110/110 [==============================] - 58s 524ms/step - loss: -0.8743 - binary_accuracy: 0.9976 - iou: 0.7856 - dice_coefficients: 0.8743 - val_loss: -0.8701 - val_binary_accuracy: 0.9962 - val_iou: 0.7708 - val_dice_coefficients: 0.8694
# Epoch 41/150
# 111/110 [==============================] - ETA: 0s - loss: -0.
val_loss did not improve from -0.91729
# 110/110 [==============================] - 58s 527ms/step - loss: -0.9137 - binary_accuracy: 0.9983 - iou: 0.8472 - dice_coefficients: 0.9138 - val_loss: -0.9085 - val_binary_accuracy: 0.9974 - val_iou: 0.8345 - val_dice_coefficients: 0.9087
# Epoch 103/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9074 - binary_accuracy: 0.9982 - iou: 0.8383 - dice_coefficients: 0.9075
# Epoch 103: val_loss did not improve from -0.91729
# 110/110 [==============================] - 58s 527ms/step - loss: -0.9074 - binary_accuracy: 0.9982 - iou: 0.8383 - dice_coefficients: 0.9075 - val_loss: -0.8997 - val_binary_accuracy: 0.9973 - val_iou: 0.8184 - val_dice_coefficients: 0.8997
# Epoch 104/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9177 - binary_accuracy: 0.9984 - iou: 0.8516 - dice_coefficients: 0.9176
# Epoch 104: val_loss improved from -0.91729 to -0.92035, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 60s 541ms/step - loss: -0.9177 - binary_accuracy: 0.9984 - iou: 0.8516 - dice_coefficients: 0.9176 - val_loss: -0.9203 - val_binary_accuracy: 0.9979 - val_iou: 0.8534 - val_dice_coefficients: 0.9206
# Epoch 105/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9133 - binary_accuracy: 0.9983 - iou: 0.8501 - dice_coefficients: 0.9134
# Epoch 105: val_loss did not improve from -0.92035
# 110/110 [==============================] - 57s 513ms/step - loss: -0.9133 - binary_accuracy: 0.9983 - iou: 0.8501 - dice_coefficients: 0.9134 - val_loss: -0.9155 - val_binary_accuracy: 0.9977 - val_iou: 0.8452 - val_dice_coefficients: 0.9156
# Epoch 106/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9128 - binary_accuracy: 0.9984 - iou: 0.8497 - dice_coefficients: 0.9128
# Epoch 106: val_loss did not improve from -0.92035
# ...
# Epoch 115/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9089 - binary_accuracy: 0.9983 - iou: 0.8435 - dice_coefficients: 0.9089
# Epoch 115: val_loss improved from -0.92035 to -0.92613, saving model to unet_brain_mri_seg.hdf5
# 110/110 [==============================] - 64s 585ms/step - loss: -0.9089 - binary_accuracy: 0.9983 - iou: 0.8435 - dice_coefficients: 0.9089 - val_loss: -0.9261 - val_binary_accuracy: 0.9978 - val_iou: 0.8629 - val_dice_coefficients: 0.9259
# Epoch 116/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9096 - binary_accuracy: 0.9982 - iou: 0.8443 - dice_coefficients: 0.9097
# Epoch 116: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 560ms/step - loss: -0.9096 - binary_accuracy: 0.9982 - iou: 0.8443 - dice_coefficients: 0.9097 - val_loss: -0.8973 - val_binary_accuracy: 0.9969 - val_iou: 0.8138 - val_dice_coefficients: 0.8970
# Epoch 117/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9100 - binary_accuracy: 0.9983 - iou: 0.8461 - dice_coefficients: 0.9101
# Epoch 117: val_loss did not improve from -0.92613
# 110/110 [==============================] - 61s 558ms/step - loss: -0.9100 - binary_accuracy: 0.9983 - iou: 0.8461 - dice_coefficients: 0.9101 - val_loss: -0.9090 - val_binary_accuracy: 0.9978 - val_iou: 0.8344 - val_dice_coefficients: 0.9082
# Epoch 118/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9101 - binary_accuracy: 0.9982 - iou: 0.8468 - dice_coefficients: 0.9102
# Epoch 118: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 564ms/step - loss: -0.9101 - binary_accuracy: 0.9982 - iou: 0.8468 - dice_coefficients: 0.9102 - val_loss: -0.9146 - val_binary_accuracy: 0.9977 - val_iou: 0.8438 - val_dice_coefficients: 0.9146
# Epoch 119/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9149 - binary_accuracy: 0.9983 - iou: 0.8520 - dice_coefficients: 0.9149
# Epoch 119: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 563ms/step - loss: -0.9149 - binary_accuracy: 0.9983 - iou: 0.8520 - dice_coefficients: 0.9149 - val_loss: -0.9037 - val_binary_accuracy: 0.9975 - val_iou: 0.8254 - val_dice_coefficients: 0.9037
# Epoch 120/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9140 - binary_accuracy: 0.9983 - iou: 0.8497 - dice_coefficients: 0.9140
# Epoch 120: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 564ms/step - loss: -0.9140 - binary_accuracy: 0.9983 - iou: 0.8497 - dice_coefficients: 0.9140 - val_loss: -0.9022 - val_binary_accuracy: 0.9972 - val_iou: 0.8223 - val_dice_coefficients: 0.9022
# Epoch 121/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9134 - binary_accuracy: 0.9983 - iou: 0.8502 - dice_coefficients: 0.9134
# Epoch 121: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 561ms/step - loss: -0.9134 - binary_accuracy: 0.9983 - iou: 0.8502 - dice_coefficients: 0.9134 - val_loss: -0.9097 - val_binary_accuracy: 0.9977 - val_iou: 0.8361 - val_dice_coefficients: 0.9097
# Epoch 122/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9112 - binary_accuracy: 0.9982 - iou: 0.8487 - dice_coefficients: 0.9113
# Epoch 122: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 564ms/step - loss: -0.9112 - binary_accuracy: 0.9982 - iou: 0.8487 - dice_coefficients: 0.9113 - val_loss: -0.9020 - val_binary_accuracy: 0.9974 - val_iou: 0.8227 - val_dice_coefficients: 0.9022
# Epoch 123/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9122 - binary_accuracy: 0.9982 - iou: 0.8500 - dice_coefficients: 0.9122
# Epoch 123: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 564ms/step - loss: -0.9122 - binary_accuracy: 0.9982 - iou: 0.8500 - dice_coefficients: 0.9122 - val_loss: -0.9157 - val_binary_accuracy: 0.9977 - val_iou: 0.8455 - val_dice_coefficients: 0.9154
# Epoch 124/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9157 - binary_accuracy: 0.9984 - iou: 0.8551 - dice_coefficients: 0.9157
# Epoch 124: val_loss did not improve from -0.92613
# 110/110 [==============================] - 62s 567ms/step - loss: -0.9157 - binary_accuracy: 0.9984 - iou: 0.8551 - dice_coefficients: 0.9157 - val_loss: -0.9077 - val_binary_accuracy: 0.9976 - val_iou: 0.8315 - val_dice_coefficients: 0.9077
# Epoch 125/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9139 - binary_accuracy: 0.9983 - iou: 0.8526 - dice_coefficients: 0.9140
# Epoch 125: val_loss did not improve from -0.92613
# 110/110 [==============================] - 65s 590ms/step - loss: -0.9139 - binary_accuracy: 0.9983 - iou: 0.8526 - dice_coefficients: 0.9140 - val_loss: -0.9083 - val_binary_accuracy: 0.9975 - val_iou: 0.8328 - val_dice_coefficients: 0.9083
# Epoch 126/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9170 - binary_accuracy: 0.9984 - iou: 0.8563 - dice_coefficients: 0.9170
# Epoch 126: val_loss did not improve from -0.92613
# 110/110 [==============================] - 65s 590ms/step - loss: -0.9170 - binary_accuracy: 0.9984 - iou: 0.8563 - dice_coefficients: 0.9170 - val_loss: -0.9077 - val_binary_accuracy: 0.9973 - val_iou: 0.8331 - val_dice_coefficients: 0.9083
# Epoch 127/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9193 - binary_accuracy: 0.9984 - iou: 0.8575 - dice_coefficients: 0.9194
# Epoch 127: val_loss did not improve from -0.92613
# 110/110 [==============================] - 64s 584ms/step - loss: -0.9193 - binary_accuracy: 0.9984 - iou: 0.8575 - dice_coefficients: 0.9194 - val_loss: -0.9033 - val_binary_accuracy: 0.9974 - val_iou: 0.8255 - val_dice_coefficients: 0.9039
# Epoch 128/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9105 - binary_accuracy: 0.9983 - iou: 0.8438 - dice_coefficients: 0.9106
# Epoch 128: val_loss did not improve from -0.92613
# 110/110 [==============================] - 63s 574ms/step - loss: -0.9105 - binary_accuracy: 0.9983 - iou: 0.8438 - dice_coefficients: 0.9106 - val_loss: -0.8932 - val_binary_accuracy: 0.9973 - val_iou: 0.8092 - val_dice_coefficients: 0.8935
# Epoch 129/150
# 111/110 [==============================] - ETA: 0s - loss: -0.0747 - binary_accuracy: 0.9540 - iou: 0.0405 - dice_coefficients: 0.0746
# Epoch 129: val_loss did not improve from -0.92613
# 110/110 [==============================] - 61s 554ms/step - loss: -0.0747 - binary_accuracy: 0.9540 - iou: 0.0405 - dice_coefficients: 0.0746 - val_loss: -0.4618 - val_binary_accuracy: 0.9817 - val_iou: 0.3024 - val_dice_coefficients: 0.4610
# Epoch 130/150
# 111/110 [==============================] - ETA: 0s - loss: -0.8638 - binary_accuracy: 0.9966 - iou: 0.7777 - dice_coefficients: 0.8639
# Epoch 130: val_loss did not improve from -0.92613
# 110/110 [==============================] - 58s 522ms/step - loss: -0.8638 - binary_accuracy: 0.9966 - iou: 0.7777 - dice_coefficients: 0.8639 - val_loss: -0.8919 - val_binary_accuracy: 0.9972 - val_iou: 0.8071 - val_dice_coefficients: 0.8925
# Epoch 131/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9027 - binary_accuracy: 0.9980 - iou: 0.8284 - dice_coefficients: 0.9027
# Epoch 131: val_loss did not improve from -0.92613
# 110/110 [==============================] - 58s 523ms/step - loss: -0.9027 - binary_accuracy: 0.9980 - iou: 0.8284 - dice_coefficients: 0.9027 - val_loss: -0.9025 - val_binary_accuracy: 0.9974 - val_iou: 0.8242 - val_dice_coefficients: 0.9027
# Epoch 132/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9109 - binary_accuracy: 0.9983 - iou: 0.8446 - dice_coefficients: 0.9109
# Epoch 132: val_loss did not improve from -0.92613
# 110/110 [==============================] - 58s 528ms/step - loss: -0.9109 - binary_accuracy: 0.9983 - iou: 0.8446 - dice_coefficients: 0.9109 - val_loss: -0.9164 - val_binary_accuracy: 0.9975 - val_iou: 0.8459 - val_dice_coefficients: 0.9162
# Epoch 133/150
# 111/110 [==============================] - ETA: 0s - loss: -0.9165 - binary_accuracy: 0.9984 - iou: 0.8534 - dice_coefficients: 0.9165
# Epoch 133: val_loss did not improve from -0.92613
# 110/110 [==============================] - 58s 526ms/step - loss: -0.9165 - binary_accuracy: 0.9984 - iou: 0.8534 - dice_coefficients: 0.9165 - val_loss: -0.9115 - val_binary_accuracy: 0.9972 - val_iou: 0.8368 - val_dice_coefficients: 0.9108
# Epoch 134/150
# 111/110 [==============================] - ETA: 0s - loss: -0.
# 110/110 [==============================] - 57s 519ms/step - loss: -0.9114 - binary_accuracy: 0.9984 - iou: 0.8473 - dice_coefficients: 0.9114 - val_loss: -0.8873 - val_binary_accuracy: 0.9969 - val_iou: 0.8010 - val_dice_coefficients: 0.8884

# %% [markdown]
# ### Plotting the metrics

# %%
history_post_training = history.history

train_dice_coeff_list = history_post_training['dice_coefficients']
test_dice_coeff_list = history_post_training['val_dice_coefficients']

train_jaccard_list = history_post_training['iou']
test_jaccard_list = history_post_training['val_iou']

train_loss_list = history_post_training['loss']
test_loss_list = history_post_training['val_loss']

plt.figure(1)
plt.plot(test_loss_list, 'b-')
plt.plot(train_loss_list, 'r-')

plt.xlabel('iterations')
plt.ylabel('loss')
plt.title('loss graph', fontsize=12)

plt.figure(2)
plt.plot(train_dice_coeff_list, 'b-')
plt.plot(test_dice_coeff_list, 'r-')

plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.title('Accuracy graph', fontsize=12)
plt.show()

# %%
display(Image(filename='Loss Graph.png'))

# %% [markdown]
# ### Evaluating the Model

# %%
from tensorflow.keras.models import load_model


model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coefficients_loss, 'iou': iou, 'dice_coef': dice_coefficients})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33358/4015858746.py in <module>
#       2
#       3
# ----> 4 model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coefficients_loss, 'iou': iou, 'dice_coef': dice_coefficients})
#
# /usr/lib/python3/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     236
#     237     # Legacy case.
# --> 238     return legacy_sm_saving_lib.load_model(
#     239         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240     )
#
# /usr/lib/python3/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/lib/python3/dist-packages/keras/saving/legacy/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     535             obj = module_objects.get(object_name)
#     536             if obj is None:
# --> 537                 raise ValueError(
#     538                     f"Unknown {printable_module_name}: '{object_name}'. "
#     539                     "Please ensure you are using a "
#
# ValueError: Unknown loss function: 'dice_coefficients_loss'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
test_gen = train_generator(df_test, BATCH_SIZE, dict(), target_size=(im_height,im_width))

results = model.evaluate(test_gen, steps = len(df_test)/BATCH_SIZE)
print('Test Loss', results[0])
print('Test IOU', results[1])
print('Test Dice Coeff', results[2])

# %% [markdown]
# ### Moment of Truth

# %%
for i in range(20):
    index = np.random.randint(1, len(df_test.index))
    img = cv2.imread(df_test['image_filename_train'].iloc[index])
    img = cv2.resize(img, (im_height,im_width))
    img = img/255
    img = img[np.newaxis, : ,:, :]
    pred_img = model.predict(img)
    
    plt.figure(figsize=(12,12))
    plt.subplot(1, 3, 1)
    plt.imshow(np.squeeze(img))
    plt.title("Original Image")
    plt.subplot(1, 3, 2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title("Original Mask")
    plt.subplot(1, 3, 3)
    plt.imshow(np.squeeze(pred_img) > 0.5)
    plt.title("Prediction")
    plt.show()
